# %% [markdown]
# # Softmax exercise
#
# *Complete and hand in this completed worksheet (including its outputs and any supporting code outside of the worksheet) with your assignment submission. For more details see the [assignments page](http://vision.stanford.edu/teaching/cs231n/assignments.html) on the course website.*
#
# This exercise is analogous to the SVM exercise. You will:
#
# - implement a fully-vectorized **loss function** for the Softmax classifier
# - implement the fully-vectorized expression for its **analytic gradient**
# - **check your implementation** with numerical gradient
# - use a validation set to **tune the learning rate and regularization** strength
# - **optimize** the loss function with **SGD**
# - **visualize** the final learned weights

# %%
import random
import numpy as np
from cs231n.data_utils import load_CIFAR10
import matplotlib.pyplot as plt

from __future__ import print_function

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading extenrnal modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# %%
def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=1000, num_dev=500):
    """
    Load the CIFAR-10 dataset from disk and perform preprocessing to prepare
    it for the linear classifier. These are the same steps as we used for the
    SVM, but condensed to a single function.  
    """
    # Load the raw CIFAR-10 data
    cifar10_dir = 'cs231n/datasets/cifar-10-batches-py'
    X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
    
    # subsample the data
    mask = list(range(num_training, num_training + num_validation))
    X_val = X_train[mask]
    y_val = y_train[mask]
    mask = list(range(num_training))
    X_train = X_train[mask]
    y_train = y_train[mask]
    mask = list(range(num_test))
    X_test = X_test[mask]
    y_test = y_test[mask]
    mask = np.random.choice(num_training, num_dev, replace=False)
    X_dev = X_train[mask]
    y_dev = y_train[mask]
    
    # Preprocessing: reshape the image data into rows
    X_train = np.reshape(X_train, (X_train.shape[0], -1))
    X_val = np.reshape(X_val, (X_val.shape[0], -1))
    X_test = np.reshape(X_test, (X_test.shape[0], -1))
    X_dev = np.reshape(X_dev, (X_dev.shape[0], -1))
    
    # Normalize the data: subtract the mean image
    mean_image = np.mean(X_train, axis = 0)
    X_train -= mean_image
    X_val -= mean_image
    X_test -= mean_image
    X_dev -= mean_image
    
    # add bias dimension and transform into columns
    X_train = np.hstack([X_train, np.ones((X_train.shape[0], 1))])
    X_val = np.hstack([X_val, np.ones((X_val.shape[0], 1))])
    X_test = np.hstack([X_test, np.ones((X_test.shape[0], 1))])
    X_dev = np.hstack([X_dev, np.ones((X_dev.shape[0], 1))])
    
    return X_train, y_train, X_val, y_val, X_test, y_test, X_dev, y_dev


# Invoke the above function to get our data.
X_train, y_train, X_val, y_val, X_test, y_test, X_dev, y_dev = get_CIFAR10_data()
print('Train data shape: ', X_train.shape)
print('Train labels shape: ', y_train.shape)
print('Validation data shape: ', X_val.shape)
print('Validation labels shape: ', y_val.shape)
print('Test data shape: ', X_test.shape)
print('Test labels shape: ', y_test.shape)
print('dev data shape: ', X_dev.shape)
print('dev labels shape: ', y_dev.shape)
# Out:
# Train data shape:  (49000, 3073)
# Train labels shape:  (49000,)
# Validation data shape:  (1000, 3073)
# Validation labels shape:  (1000,)
# Test data shape:  (1000, 3073)
# Test labels shape:  (1000,)
# dev data shape:  (500, 3073)
# dev labels shape:  (500,)

# %% [markdown]
# ## Softmax Classifier
#
# Your code for this section will all be written inside **cs231n/classifiers/softmax.py**.

# %%
# First implement the naive softmax loss function with nested loops.
# Open the file cs231n/classifiers/softmax.py and implement the
# softmax_loss_naive function.

from cs231n.classifiers.softmax import softmax_loss_naive
import time

# Generate a random softmax weight matrix and use it to compute the loss.
W = np.random.randn(3073, 10) * 0.0001
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 0.0)

# As a rough sanity check, our loss should be something close to -log(0.1).
print('loss: %f' % loss)
print('sanity check: %f' % (-np.log(0.1)))
# Out:
# loss: 2.318296
# sanity check: 2.302585

# %% [markdown]
# ## Inline Question 1:
# Why do we expect our loss to be close to -log(0.1)? Explain briefly.**
#
# **Your answer:** because the W is not the result we want at first, the right class should have a small score

# %%
# Complete the implementation of softmax_loss_naive and implement a (naive)
# version of the gradient that uses nested loops.
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 0.0)

# As we did for the SVM, use numeric gradient checking as a debugging tool.
# The numeric gradient should be close to the analytic gradient.
from cs231n.gradient_check import grad_check_sparse
f = lambda w: softmax_loss_naive(w, X_dev, y_dev, 0.0)[0]
grad_numerical = grad_check_sparse(f, W, grad, 10)

# similar to SVM case, do another gradient check with regularization
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 5e1)
f = lambda w: softmax_loss_naive(w, X_dev, y_dev, 5e1)[0]
grad_numerical = grad_check_sparse(f, W, grad, 10)
# Out:
# numerical: -0.198498 analytic: -0.198498, relative error: 6.706163e-08
# numerical: 0.354682 analytic: 0.354682, relative error: 1.428311e-07
# numerical: -0.616475 analytic: -0.616475, relative error: 5.449600e-08
# numerical: -0.685827 analytic: -0.685827, relative error: 1.513163e-08
# numerical: 0.426714 analytic: 0.426714, relative error: 6.702328e-08
# numerical: -2.526755 analytic: -2.526755, relative error: 6.903251e-09
# numerical: -1.458538 analytic: -1.458538, relative error: 4.081841e-08
# numerical: 0.627239 analytic: 0.627239, relative error: 1.815073e-08
# numerical: 2.959830 analytic: 2.959830, relative error: 2.342355e-08
# numerical: -2.169713 analytic: -2.169713, relative error: 2.331166e-08
# numerical: 0.336555 analytic: 0.336555, relative error: 1.206803e-08
# numerical: 1.741137 analytic: 1.741137, relative error: 1.251284e-08
# numerical: -3.303366 analytic: -3.303366, relative error: 7.658522e-09
# numerical: 0.593791 analytic: 0.593791, relative error: 6.671006e-09
# numerical: -4.604937 analytic: -4.604937, relative error: 8.462322e-09
# numerical: -1.738489 analytic: -1.738489, relative error: 1.039441e-08
# numerical: -1.096660 analytic: -1.096660, relative error: 1.990875e-08
# numerical: -2.778148 analytic: -2.778148, relative error: 3.899492e-09
# numerical: -1.727894 analytic: -1.727895, relative error: 3.263951e-09
# numerical: 2.099679 analytic: 2.099679, relative error: 2.277219e-08

# %%
# Now that we have a naive implementation of the softmax loss function and its gradient,
# implement a vectorized version in softmax_loss_vectorized.
# The two versions should compute the same results, but the vectorized version should be
# much faster.
tic = time.time()
loss_naive, grad_naive = softmax_loss_naive(W, X_dev, y_dev, 0.000005)
toc = time.time()
print('naive loss: %e computed in %fs' % (loss_naive, toc - tic))

from cs231n.classifiers.softmax import softmax_loss_vectorized
tic = time.time()
loss_vectorized, grad_vectorized = softmax_loss_vectorized(W, X_dev, y_dev, 0.000005)
toc = time.time()
print('vectorized loss: %e computed in %fs' % (loss_vectorized, toc - tic))

# As we did for the SVM, we use the Frobenius norm to compare the two versions
# of the gradient.
grad_difference = np.linalg.norm(grad_naive - grad_vectorized, ord='fro')
print('Loss difference: %f' % np.abs(loss_naive - loss_vectorized))
print('Gradient difference: %f' % grad_difference)

# %%
# Use the validation set to tune hyperparameters (regularization strength and
# learning rate). You should experiment with different ranges for the learning
# rates and regularization strengths; if you are careful you should be able to
# get a classification accuracy of over 0.35 on the validation set.
from cs231n.classifiers import Softmax
results = {}
best_val = -1
best_softmax = None
learning_rates = [5e-7, 5e-6, 1e-5, 5e-5, 1e-4, 3e-4, 7e-4, 1e-3, 3e-3, 5e-3, 7e-3, 1e-2, 5e-2, 1e-1,
                 5e-1, 1, 3, 5]
regularization_strengths = [5e-5, 2.5e-4, 5e-4,2.5e-3,5e-3,7.5e-3,9.5e-3,2.5e-2,7.5e-2,9.5e-2,1e-1,5e-1,1,3]

################################################################################
# TODO:                                                                        #
# Use the validation set to set the learning rate and regularization strength. #
# This should be identical to the validation that you did for the SVM; save    #
# the best trained softmax classifer in best_softmax.                          #
################################################################################
for learning_rate in learning_rates:
    for reg in regularization_strengths:
        softmax = Softmax()
        softmax.train(X_train, y_train, learning_rate, reg,
                      num_iters=1500, verbose=False)
        y_train_pred = softmax.predict(X_train)
        y_val_pred = softmax.predict(X_val)
        y_train_accuracy = np.mean(y_train_pred == y_train)
        y_val_accuracy = np.mean(y_val_pred == y_val)
        results[(learning_rate,reg)] = (y_train_accuracy,y_val_accuracy)
        if best_val<y_val_accuracy:
            best_val = y_val_accuracy
            best_softmax = softmax
################################################################################
#                              END OF YOUR CODE                                #
################################################################################
    
# Print out results.
for lr, reg in sorted(results):
    train_accuracy, val_accuracy = results[(lr, reg)]
    print('lr %e reg %e train accuracy: %f val accuracy: %f' % (
                lr, reg, train_accuracy, val_accuracy))
    
print('best validation accuracy achieved during cross-validation: %f' % best_val)
# Out:
# /home/zyl/projects/cs231n/assignment1/cs231n/classifiers/softmax.py:78: RuntimeWarning: divide by zero encountered in log
#   '''
# /home/zyl/projects/cs231n/assignment1/cs231n/classifiers/softmax.py:78: RuntimeWarning: overflow encountered in double_scalars
#   '''
# /home/zyl/projects/cs231n/assignment1/cs231n/classifiers/softmax.py:78: RuntimeWarning: overflow encountered in multiply
#   '''
# /home/zyl/projects/cs231n/assignment1/cs231n/classifiers/softmax.py:73: RuntimeWarning: overflow encountered in subtract
#   exp_score = np.exp(origin_score)
# lr 5.000000e-07 reg 5.000000e-05 train accuracy: 0.314327 val accuracy: 0.307000
# lr 5.000000e-07 reg 2.500000e-04 train accuracy: 0.314143 val accuracy: 0.309000
# lr 5.000000e-07 reg 5.000000e-04 train accuracy: 0.320551 val accuracy: 0.331000
# lr 5.000000e-07 reg 2.500000e-03 train accuracy: 0.317510 val accuracy: 0.306000
# lr 5.000000e-07 reg 5.000000e-03 train accuracy: 0.319429 val accuracy: 0.336000
# lr 5.000000e-07 reg 7.500000e-03 train accuracy: 0.316510 val accuracy: 0.322000
# lr 5.000000e-07 reg 9.500000e-03 train accuracy: 0.320612 val accuracy: 0.305000
# lr 5.000000e-07 reg 2.500000e-02 train accuracy: 0.320592 val accuracy: 0.348000
# lr 5.000000e-07 reg 7.500000e-02 train accuracy: 0.321449 val accuracy: 0.328000
# lr 5.000000e-07 reg 9.500000e-02 train accuracy: 0.324163 val accuracy: 0.327000
# lr 5.000000e-07 reg 1.000000e-01 train accuracy: 0.319306 val accuracy: 0.335000
# lr 5.000000e-07 reg 5.000000e-01 train accuracy: 0.321020 val accuracy: 0.304000
# lr 5.000000e-07 reg 1.000000e+00 train accuracy: 0.322816 val accuracy: 0.302000
# lr 5.000000e-07 reg 3.000000e+00 train accuracy: 0.318755 val accuracy: 0.331000
# lr 5.000000e-06 reg 5.000000e-05 train accuracy: 0.390694 val accuracy: 0.364000
# lr 5.000000e-06 reg 2.500000e-04 train accuracy: 0.392959 val accuracy: 0.366000
# lr 5.000000e-06 reg 5.000000e-04 train accuracy: 0.386490 val accuracy: 0.361000
# lr 5.000000e-06 reg 2.500000e-03 train accuracy: 0.399429 val accuracy: 0.375000
# lr 5.000000e-06 reg 5.000000e-03 train accuracy: 0.384306 val accuracy: 0.370000
# lr 5.000000e-06 reg 7.500000e-03 train accuracy: 0.363490 val accuracy: 0.359000
# lr 5.000000e-06 reg 9.500000e-03 train accuracy: 0.375388 val accuracy: 0.347000
# lr 5.000000e-06 reg 2.500000e-02 train accuracy: 0.392265 val accuracy: 0.335000
# lr 5.000000e-06 reg 7.500000e-02 train accuracy: 0.404714 val accuracy: 0.364000
# lr 5.000000e-06 reg 9.500000e-02 train accuracy: 0.388163 val accuracy: 0.379000
# lr 5.000000e-06 reg 1.000000e-01 train accuracy: 0.383102 val accuracy: 0.372000
# lr 5.000000e-06 reg 5.000000e-01 train accuracy: 0.390878 val accuracy: 0.357000
# lr 5.000000e-06 reg 1.000000e+00 train accuracy: 0.388327 val accuracy: 0.366000
# lr 5.000000e-06 reg 3.000000e+00 train accuracy: 0.393041 val accuracy: 0.369000
# lr 1.000000e-05 reg 5.000000e-05 train accuracy: 0.332571 val accuracy: 0.309000
# lr 1.000000e-05 reg 2.500000e-04 train accuracy: 0.319939 val accuracy: 0.278000
# lr 1.000000e-05 reg 5.000000e-04 train accuracy: 0.327449 val accuracy: 0.313000
# lr 1.000000e-05 reg 2.500000e-03 train accuracy: 0.337184 val accuracy: 0.342000
# lr 1.000000e-05 reg 5.000000e-03 train accuracy: 0.371449 val accuracy: 0.356000
# lr 1.000000e-05 reg 7.500000e-03 train accuracy: 0.303469 val accuracy: 0.285000
# lr 1.000000e-05 reg 9.500000e-03 train accuracy: 0.331755 val accuracy: 0.301000
# lr 1.000000e-05 reg 2.500000e-02 train accuracy: 0.352449 val accuracy: 0.336000
# lr 1.000000e-05 reg 7.500000e-02 train accuracy: 0.335327 val accuracy: 0.316000
# lr 1.000000e-05 reg 9.500000e-02 train accuracy: 0.298918 val accuracy: 0.315000
# lr 1.000000e-05 reg 1.000000e-01 train accuracy: 0.354449 val accuracy: 0.338000
# lr 1.000000e-05 reg 5.000000e-01 train accuracy: 0.294878 val accuracy: 0.298000
# lr 1.000000e-05 reg 1.000000e+00 train accuracy: 0.394939 val accuracy: 0.374000
# lr 1.000000e-05 reg 3.000000e+00 train accuracy: 0.306571 val accuracy: 0.288000
# lr 5.000000e-05 reg 5.000000e-05 train accuracy: 0.229531 val accuracy: 0.205000
# lr 5.000000e-05 reg 2.500000e-04 train accuracy: 0.316367 val accuracy: 0.296000
# lr 5.000000e-05 reg 5.000000e-04 train accuracy: 0.345980 val accuracy: 0.348000
# lr 5.000000e-05 reg 2.500000e-03 train accuracy: 0.286347 val accuracy: 0.273000
# lr 5.000000e-05 reg 5.000000e-03 train accuracy: 0.317347 val accuracy: 0.304000
# lr 5.000000e-05 reg 7.500000e-03 train accuracy: 0.311347 val accuracy: 0.314000
# lr 5.000000e-05 reg 9.500000e-03 train accuracy: 0.290796 val accuracy: 0.292000
# lr 5.000000e-05 reg 2.500000e-02 train accuracy: 0.293796 val accuracy: 0.262000
# lr 5.000000e-05 reg 7.500000e-02 train accuracy: 0.296510 val accuracy: 0.301000
# lr 5.000000e-05 reg 9.500000e-02 train accuracy: 0.310837 val accuracy: 0.297000
# lr 5.000000e-05 reg 1.000000e-01 train accuracy: 0.273143 val accuracy: 0.268000
# lr 5.000000e-05 reg 5.000000e-01 train accuracy: 0.297857 val accuracy: 0.279000
# lr 5.000000e-05 reg 1.000000e+00 train accuracy: 0.272612 val accuracy: 0.235000
# lr 5.000000e-05 reg 3.000000e+00 train accuracy: 0.312000 val accuracy: 0.286000
# lr 1.000000e-04 reg 5.000000e-05 train accuracy: 0.295918 val accuracy: 0.291000
# lr 1.000000e-04 reg 2.500000e-04 train accuracy: 0.319102 val accuracy: 0.286000
# lr 1.000000e-04 reg 5.000000e-04 train accuracy: 0.298980 val accuracy: 0.295000
# lr 1.000000e-04 reg 2.500000e-03 train accuracy: 0.273510 val accuracy: 0.271000
# lr 1.000000e-04 reg 5.000000e-03 train accuracy: 0.296918 val accuracy: 0.298000
# lr 1.000000e-04 reg 7.500000e-03 train accuracy: 0.288510 val accuracy: 0.299000
# lr 1.000000e-04 reg 9.500000e-03 train accuracy: 0.323469 val accuracy: 0.303000
# lr 1.000000e-04 reg 2.500000e-02 train accuracy: 0.271041 val accuracy: 0.276000
# lr 1.000000e-04 reg 7.500000e-02 train accuracy: 0.282469 val accuracy: 0.268000
# lr 1.000000e-04 reg 9.500000e-02 train accuracy: 0.279939 val accuracy: 0.232000
# lr 1.000000e-04 reg 1.000000e-01 train accuracy: 0.278388 val accuracy: 0.260000
# lr 1.000000e-04 reg 5.000000e-01 train accuracy: 0.327122 val accuracy: 0.286000
# lr 1.000000e-04 reg 1.000000e+00 train accuracy: 0.345490 val accuracy: 0.333000
# lr 1.000000e-04 reg 3.000000e+00 train accuracy: 0.291327 val accuracy: 0.274000
# lr 3.000000e-04 reg 5.000000e-05 train accuracy: 0.331918 val accuracy: 0.309000
# lr 3.000000e-04 reg 2.500000e-04 train accuracy: 0.309653 val accuracy: 0.290000
# lr 3.000000e-04 reg 5.000000e-04 train accuracy: 0.267714 val accuracy: 0.264000
# lr 3.000000e-04 reg 2.500000e-03 train accuracy: 0.297939 val accuracy: 0.276000
# lr 3.000000e-04 reg 5.000000e-03 train accuracy: 0.284449 val accuracy: 0.258000
# lr 3.000000e-04 reg 7.500000e-03 train accuracy: 0.300388 val accuracy: 0.296000
# lr 3.000000e-04 reg 9.500000e-03 train accuracy: 0.272612 val accuracy: 0.253000
# lr 3.000000e-04 reg 2.500000e-02 train accuracy: 0.328347 val accuracy: 0.308000
# lr 3.000000e-04 reg 7.500000e-02 train accuracy: 0.283020 val accuracy: 0.268000
# lr 3.000000e-04 reg 9.500000e-02 train accuracy: 0.292755 val accuracy: 0.282000
# lr 3.000000e-04 reg 1.000000e-01 train accuracy: 0.306041 val accuracy: 0.310000
# lr 3.000000e-04 reg 5.000000e-01 train accuracy: 0.290694 val accuracy: 0.298000
# lr 3.000000e-04 reg 1.000000e+00 train accuracy: 0.255041 val accuracy: 0.240000
# lr 3.000000e-04 reg 3.000000e+00 train accuracy: 0.311490 val accuracy: 0.299000
# lr 7.000000e-04 reg 5.000000e-05 train accuracy: 0.322714 val accuracy: 0.284000
# lr 7.000000e-04 reg 2.500000e-04 train accuracy: 0.314204 val accuracy: 0.288000
# lr 7.000000e-04 reg 5.000000e-04 train accuracy: 0.308980 val accuracy: 0.295000
# lr 7.000000e-04 reg 2.500000e-03 train accuracy: 0.289735 val accuracy: 0.284000
# lr 7.000000e-04 reg 5.000000e-03 train accuracy: 0.285429 val accuracy: 0.274000
# lr 7.000000e-04 reg 7.500000e-03 train accuracy: 0.301776 val accuracy: 0.279000
# lr 7.000000e-04 reg 9.500000e-03 train accuracy: 0.266837 val accuracy: 0.264000
# lr 7.000000e-04 reg 2.500000e-02 train accuracy: 0.286224 val accuracy: 0.258000
# lr 7.000000e-04 reg 7.500000e-02 train accuracy: 0.263592 val accuracy: 0.249000
# lr 7.000000e-04 reg 9.500000e-02 train accuracy: 0.331939 val accuracy: 0.320000
# lr 7.000000e-04 reg 1.000000e-01 train accuracy: 0.281163 val accuracy: 0.278000
# lr 7.000000e-04 reg 5.000000e-01 train accuracy: 0.284918 val accuracy: 0.259000
# lr 7.000000e-04 reg 1.000000e+00 train accuracy: 0.263551 val accuracy: 0.274000
# lr 7.000000e-04 reg 3.000000e+00 train accuracy: 0.239082 val accuracy: 0.220000
# lr 1.000000e-03 reg 5.000000e-05 train accuracy: 0.310245 val accuracy: 0.289000
# lr 1.000000e-03 reg 2.500000e-04 train accuracy: 0.315102 val accuracy: 0.281000
# lr 1.000000e-03 reg 5.000000e-04 train accuracy: 0.325184 val accuracy: 0.302000
# lr 1.000000e-03 reg 2.500000e-03 train accuracy: 0.314306 val accuracy: 0.295000
# lr 1.000000e-03 reg 5.000000e-03 train accuracy: 0.281980 val accuracy: 0.278000
# lr 1.000000e-03 reg 7.500000e-03 train accuracy: 0.287000 val accuracy: 0.279000
# lr 1.000000e-03 reg 9.500000e-03 train accuracy: 0.318184 val accuracy: 0.311000
# lr 1.000000e-03 reg 2.500000e-02 train accuracy: 0.230755 val accuracy: 0.218000
# lr 1.000000e-03 reg 7.500000e-02 train accuracy: 0.295816 val accuracy: 0.304000
# lr 1.000000e-03 reg 9.500000e-02 train accuracy: 0.300204 val accuracy: 0.292000
# lr 1.000000e-03 reg 1.000000e-01 train accuracy: 0.286061 val accuracy: 0.271000
# lr 1.000000e-03 reg 5.000000e-01 train accuracy: 0.240347 val accuracy: 0.231000
# lr 1.000000e-03 reg 1.000000e+00 train accuracy: 0.298286 val accuracy: 0.287000
# lr 1.000000e-03 reg 3.000000e+00 train accuracy: 0.281959 val accuracy: 0.304000
# lr 3.000000e-03 reg 5.000000e-05 train accuracy: 0.331551 val accuracy: 0.306000
# lr 3.000000e-03 reg 2.500000e-04 train accuracy: 0.336082 val accuracy: 0.332000
# lr 3.000000e-03 reg 5.000000e-04 train accuracy: 0.301469 val accuracy: 0.288000
# lr 3.000000e-03 reg 2.500000e-03 train accuracy: 0.328265 val accuracy: 0.305000
# lr 3.000000e-03 reg 5.000000e-03 train accuracy: 0.235061 val accuracy: 0.220000
# lr 3.000000e-03 reg 7.500000e-03 train accuracy: 0.283082 val accuracy: 0.256000
# lr 3.000000e-03 reg 9.500000e-03 train accuracy: 0.251490 val accuracy: 0.259000
# lr 3.000000e-03 reg 2.500000e-02 train accuracy: 0.283245 val accuracy: 0.275000
# lr 3.000000e-03 reg 7.500000e-02 train accuracy: 0.284245 val accuracy: 0.280000
# lr 3.000000e-03 reg 9.500000e-02 train accuracy: 0.290510 val accuracy: 0.283000
# lr 3.000000e-03 reg 1.000000e-01 train accuracy: 0.290204 val accuracy: 0.289000
# lr 3.000000e-03 reg 5.000000e-01 train accuracy: 0.281959 val accuracy: 0.265000
# lr 3.000000e-03 reg 1.000000e+00 train accuracy: 0.246265 val accuracy: 0.259000
# lr 3.000000e-03 reg 3.000000e+00 train accuracy: 0.226878 val accuracy: 0.237000
# lr 5.000000e-03 reg 5.000000e-05 train accuracy: 0.280633 val accuracy: 0.280000
# lr 5.000000e-03 reg 2.500000e-04 train accuracy: 0.317490 val accuracy: 0.282000
# lr 5.000000e-03 reg 5.000000e-04 train accuracy: 0.298041 val accuracy: 0.282000
# lr 5.000000e-03 reg 2.500000e-03 train accuracy: 0.284551 val accuracy: 0.273000
# lr 5.000000e-03 reg 5.000000e-03 train accuracy: 0.308857 val accuracy: 0.293000
# lr 5.000000e-03 reg 7.500000e-03 train accuracy: 0.322714 val accuracy: 0.305000
# lr 5.000000e-03 reg 9.500000e-03 train accuracy: 0.283286 val accuracy: 0.278000
# lr 5.000000e-03 reg 2.500000e-02 train accuracy: 0.286633 val accuracy: 0.289000
# lr 5.000000e-03 reg 7.500000e-02 train accuracy: 0.257469 val accuracy: 0.238000
# lr 5.000000e-03 reg 9.500000e-02 train accuracy: 0.253265 val accuracy: 0.237000
# lr 5.000000e-03 reg 1.000000e-01 train accuracy: 0.233122 val accuracy: 0.235000
# lr 5.000000e-03 reg 5.000000e-01 train accuracy: 0.294265 val accuracy: 0.310000
# lr 5.000000e-03 reg 1.000000e+00 train accuracy: 0.229918 val accuracy: 0.220000
# lr 5.000000e-03 reg 3.000000e+00 train accuracy: 0.210224 val accuracy: 0.223000
# lr 7.000000e-03 reg 5.000000e-05 train accuracy: 0.272245 val accuracy: 0.282000
# lr 7.000000e-03 reg 2.500000e-04 train accuracy: 0.250245 val accuracy: 0.245000
# lr 7.000000e-03 reg 5.000000e-04 train accuracy: 0.320959 val accuracy: 0.271000
# lr 7.000000e-03 reg 2.500000e-03 train accuracy: 0.296776 val accuracy: 0.284000
# lr 7.000000e-03 reg 5.000000e-03 train accuracy: 0.294408 val accuracy: 0.277000
# lr 7.000000e-03 reg 7.500000e-03 train accuracy: 0.279082 val accuracy: 0.290000
# lr 7.000000e-03 reg 9.500000e-03 train accuracy: 0.332000 val accuracy: 0.302000
# lr 7.000000e-03 reg 2.500000e-02 train accuracy: 0.269163 val accuracy: 0.262000
# lr 7.000000e-03 reg 7.500000e-02 train accuracy: 0.236143 val accuracy: 0.224000
# lr 7.000000e-03 reg 9.500000e-02 train accuracy: 0.284490 val accuracy: 0.289000
# lr 7.000000e-03 reg 1.000000e-01 train accuracy: 0.267980 val accuracy: 0.278000
# lr 7.000000e-03 reg 5.000000e-01 train accuracy: 0.234041 val accuracy: 0.237000
# lr 7.000000e-03 reg 1.000000e+00 train accuracy: 0.232755 val accuracy: 0.232000
# lr 7.000000e-03 reg 3.000000e+00 train accuracy: 0.254041 val accuracy: 0.257000
# lr 1.000000e-02 reg 5.000000e-05 train accuracy: 0.277102 val accuracy: 0.253000
# lr 1.000000e-02 reg 2.500000e-04 train accuracy: 0.231551 val accuracy: 0.239000
# lr 1.000000e-02 reg 5.000000e-04 train accuracy: 0.253020 val accuracy: 0.244000
# lr 1.000000e-02 reg 2.500000e-03 train accuracy: 0.285980 val accuracy: 0.267000
# lr 1.000000e-02 reg 5.000000e-03 train accuracy: 0.303878 val accuracy: 0.298000
# lr 1.000000e-02 reg 7.500000e-03 train accuracy: 0.240837 val accuracy: 0.232000
# lr 1.000000e-02 reg 9.500000e-03 train accuracy: 0.325714 val accuracy: 0.327000
# lr 1.000000e-02 reg 2.500000e-02 train accuracy: 0.246714 val accuracy: 0.236000
# lr 1.000000e-02 reg 7.500000e-02 train accuracy: 0.254245 val accuracy: 0.244000
# lr 1.000000e-02 reg 9.500000e-02 train accuracy: 0.262204 val accuracy: 0.257000
# lr 1.000000e-02 reg 1.000000e-01 train accuracy: 0.299286 val accuracy: 0.303000
# lr 1.000000e-02 reg 5.000000e-01 train accuracy: 0.267122 val accuracy: 0.310000
# lr 1.000000e-02 reg 1.000000e+00 train accuracy: 0.237000 val accuracy: 0.242000
# lr 1.000000e-02 reg 3.000000e+00 train accuracy: 0.223286 val accuracy: 0.197000
# lr 5.000000e-02 reg 5.000000e-05 train accuracy: 0.297510 val accuracy: 0.294000
# lr 5.000000e-02 reg 2.500000e-04 train accuracy: 0.278490 val accuracy: 0.273000
# lr 5.000000e-02 reg 5.000000e-04 train accuracy: 0.324265 val accuracy: 0.305000
# lr 5.000000e-02 reg 2.500000e-03 train accuracy: 0.328673 val accuracy: 0.305000
# lr 5.000000e-02 reg 5.000000e-03 train accuracy: 0.273082 val accuracy: 0.271000
# lr 5.000000e-02 reg 7.500000e-03 train accuracy: 0.266306 val accuracy: 0.235000
# lr 5.000000e-02 reg 9.500000e-03 train accuracy: 0.302898 val accuracy: 0.285000
# lr 5.000000e-02 reg 2.500000e-02 train accuracy: 0.275204 val accuracy: 0.267000
# lr 5.000000e-02 reg 7.500000e-02 train accuracy: 0.260020 val accuracy: 0.248000
# lr 5.000000e-02 reg 9.500000e-02 train accuracy: 0.284408 val accuracy: 0.279000
# lr 5.000000e-02 reg 1.000000e-01 train accuracy: 0.225510 val accuracy: 0.225000
# lr 5.000000e-02 reg 5.000000e-01 train accuracy: 0.250612 val accuracy: 0.274000
# lr 5.000000e-02 reg 1.000000e+00 train accuracy: 0.164878 val accuracy: 0.164000
# lr 5.000000e-02 reg 3.000000e+00 train accuracy: 0.134551 val accuracy: 0.138000
# lr 1.000000e-01 reg 5.000000e-05 train accuracy: 0.320041 val accuracy: 0.310000
# lr 1.000000e-01 reg 2.500000e-04 train accuracy: 0.307265 val accuracy: 0.289000
# lr 1.000000e-01 reg 5.000000e-04 train accuracy: 0.307408 val accuracy: 0.288000
# lr 1.000000e-01 reg 2.500000e-03 train accuracy: 0.312551 val accuracy: 0.297000
# lr 1.000000e-01 reg 5.000000e-03 train accuracy: 0.250020 val accuracy: 0.237000
# lr 1.000000e-01 reg 7.500000e-03 train accuracy: 0.270082 val accuracy: 0.277000
# lr 1.000000e-01 reg 9.500000e-03 train accuracy: 0.268306 val accuracy: 0.265000
# lr 1.000000e-01 reg 2.500000e-02 train accuracy: 0.229653 val accuracy: 0.250000
# lr 1.000000e-01 reg 7.500000e-02 train accuracy: 0.236694 val accuracy: 0.263000
# lr 1.000000e-01 reg 9.500000e-02 train accuracy: 0.216878 val accuracy: 0.231000
# lr 1.000000e-01 reg 1.000000e-01 train accuracy: 0.226980 val accuracy: 0.233000
# lr 1.000000e-01 reg 5.000000e-01 train accuracy: 0.160367 val accuracy: 0.150000
# lr 1.000000e-01 reg 1.000000e+00 train accuracy: 0.124531 val accuracy: 0.113000
# lr 1.000000e-01 reg 3.000000e+00 train accuracy: 0.163163 val accuracy: 0.157000
# lr 5.000000e-01 reg 5.000000e-05 train accuracy: 0.301878 val accuracy: 0.283000
# lr 5.000000e-01 reg 2.500000e-04 train accuracy: 0.303306 val accuracy: 0.299000
# lr 5.000000e-01 reg 5.000000e-04 train accuracy: 0.288163 val accuracy: 0.276000
# lr 5.000000e-01 reg 2.500000e-03 train accuracy: 0.274204 val accuracy: 0.272000
# lr 5.000000e-01 reg 5.000000e-03 train accuracy: 0.251286 val accuracy: 0.248000
# lr 5.000000e-01 reg 7.500000e-03 train accuracy: 0.258898 val accuracy: 0.248000
# lr 5.000000e-01 reg 9.500000e-03 train accuracy: 0.259490 val accuracy: 0.290000
# lr 5.000000e-01 reg 2.500000e-02 train accuracy: 0.249143 val accuracy: 0.252000
# lr 5.000000e-01 reg 7.500000e-02 train accuracy: 0.222469 val accuracy: 0.242000
# lr 5.000000e-01 reg 9.500000e-02 train accuracy: 0.180367 val accuracy: 0.190000
# lr 5.000000e-01 reg 1.000000e-01 train accuracy: 0.147327 val accuracy: 0.135000
# lr 5.000000e-01 reg 5.000000e-01 train accuracy: 0.126612 val accuracy: 0.106000
# lr 5.000000e-01 reg 1.000000e+00 train accuracy: 0.070571 val accuracy: 0.050000
# lr 5.000000e-01 reg 3.000000e+00 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e+00 reg 5.000000e-05 train accuracy: 0.285469 val accuracy: 0.257000
# lr 1.000000e+00 reg 2.500000e-04 train accuracy: 0.313163 val accuracy: 0.321000
# lr 1.000000e+00 reg 5.000000e-04 train accuracy: 0.268673 val accuracy: 0.246000
# lr 1.000000e+00 reg 2.500000e-03 train accuracy: 0.286551 val accuracy: 0.299000
# lr 1.000000e+00 reg 5.000000e-03 train accuracy: 0.241796 val accuracy: 0.227000
# lr 1.000000e+00 reg 7.500000e-03 train accuracy: 0.237592 val accuracy: 0.241000
# lr 1.000000e+00 reg 9.500000e-03 train accuracy: 0.243959 val accuracy: 0.243000
# lr 1.000000e+00 reg 2.500000e-02 train accuracy: 0.271306 val accuracy: 0.289000
# lr 1.000000e+00 reg 7.500000e-02 train accuracy: 0.189041 val accuracy: 0.192000
# lr 1.000000e+00 reg 9.500000e-02 train accuracy: 0.196714 val accuracy: 0.218000
# lr 1.000000e+00 reg 1.000000e-01 train accuracy: 0.174612 val accuracy: 0.196000
# lr 1.000000e+00 reg 5.000000e-01 train accuracy: 0.083245 val accuracy: 0.083000
# lr 1.000000e+00 reg 1.000000e+00 train accuracy: 0.069122 val accuracy: 0.051000
# lr 1.000000e+00 reg 3.000000e+00 train accuracy: 0.100265 val accuracy: 0.087000
# lr 3.000000e+00 reg 5.000000e-05 train accuracy: 0.278184 val accuracy: 0.290000
# lr 3.000000e+00 reg 2.500000e-04 train accuracy: 0.265776 val accuracy: 0.276000
# lr 3.000000e+00 reg 5.000000e-04 train accuracy: 0.305776 val accuracy: 0.310000
# lr 3.000000e+00 reg 2.500000e-03 train accuracy: 0.272469 val accuracy: 0.285000
# lr 3.000000e+00 reg 5.000000e-03 train accuracy: 0.224980 val accuracy: 0.243000
# lr 3.000000e+00 reg 7.500000e-03 train accuracy: 0.173510 val accuracy: 0.195000
# lr 3.000000e+00 reg 9.500000e-03 train accuracy: 0.213143 val accuracy: 0.222000
# lr 3.000000e+00 reg 2.500000e-02 train accuracy: 0.162531 val accuracy: 0.156000
# lr 3.000000e+00 reg 7.500000e-02 train accuracy: 0.112510 val accuracy: 0.112000
# lr 3.000000e+00 reg 9.500000e-02 train accuracy: 0.186980 val accuracy: 0.172000
# lr 3.000000e+00 reg 1.000000e-01 train accuracy: 0.165592 val accuracy: 0.163000
# lr 3.000000e+00 reg 5.000000e-01 train accuracy: 0.100265 val accuracy: 0.087000
# lr 3.000000e+00 reg 1.000000e+00 train accuracy: 0.100265 val accuracy: 0.087000
# lr 3.000000e+00 reg 3.000000e+00 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.000000e+00 reg 5.000000e-05 train accuracy: 0.294898 val accuracy: 0.298000
# lr 5.000000e+00 reg 2.500000e-04 train accuracy: 0.292633 val accuracy: 0.291000
# lr 5.000000e+00 reg 5.000000e-04 train accuracy: 0.266694 val accuracy: 0.255000
# lr 5.000000e+00 reg 2.500000e-03 train accuracy: 0.227041 val accuracy: 0.230000
# lr 5.000000e+00 reg 5.000000e-03 train accuracy: 0.166939 val accuracy: 0.179000
# lr 5.000000e+00 reg 7.500000e-03 train accuracy: 0.126673 val accuracy: 0.124000
# lr 5.000000e+00 reg 9.500000e-03 train accuracy: 0.171184 val accuracy: 0.175000
# lr 5.000000e+00 reg 2.500000e-02 train accuracy: 0.136163 val accuracy: 0.142000
# lr 5.000000e+00 reg 7.500000e-02 train accuracy: 0.096837 val accuracy: 0.092000
# lr 5.000000e+00 reg 9.500000e-02 train accuracy: 0.077041 val accuracy: 0.077000
# lr 5.000000e+00 reg 1.000000e-01 train accuracy: 0.149694 val accuracy: 0.143000
# lr 5.000000e+00 reg 5.000000e-01 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.000000e+00 reg 1.000000e+00 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.000000e+00 reg 3.000000e+00 train accuracy: 0.100265 val accuracy: 0.087000
# best validation accuracy achieved during cross-validation: 0.379000
# /home/zyl/projects/cs231n/assignment1/cs231n/classifiers/softmax.py:73: RuntimeWarning: invalid value encountered in subtract
#   exp_score = np.exp(origin_score)

# %%
# evaluate on test set
# Evaluate the best softmax on test set
y_test_pred = best_softmax.predict(X_test)
test_accuracy = np.mean(y_test == y_test_pred)
print('softmax on raw pixels final test set accuracy: %f' % (test_accuracy, ))
# Out:
# softmax on raw pixels final test set accuracy: 0.375000

# %%
# Visualize the learned weights for each class
w = best_softmax.W[:-1,:] # strip out the bias
w = w.reshape(32, 32, 3, 10)

w_min, w_max = np.min(w), np.max(w)

classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
for i in range(10):
    plt.subplot(2, 5, i + 1)
    
    # Rescale the weights to be between 0 and 255
    wimg = 255.0 * (w[:, :, :, i].squeeze() - w_min) / (w_max - w_min)
    plt.imshow(wimg.astype('uint8'))
    plt.axis('off')
    plt.title(classes[i])
